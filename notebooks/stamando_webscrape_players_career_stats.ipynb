# %%
import requests
from bs4 import BeautifulSoup as bs
from IPython.core.display import HTML
import pandas as pd

# %%
URL = 'https://statmando.com/players/'

response = requests.get(URL)

# %%
response.status_code
# Out:
# 200

# %%
response.text ##call URL html and show as text
soup = bs(response.text) ##soupify response
print(soup.prettify()) ##print in a more readable form
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    StatMando Player Profiles | StatMando - Disc Golf's Statistics Platform
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=3, minimum-scale=1, user-scalable=yes" name="viewport"/>
#   <link href="/images/logo.png" rel="shortcut icon" type="image/png"/>
#   <link href="https://use.fontawesome.com/releases/v5.8.1/css/all.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.datatables.net/v/dt/dt-1.10.24/b-1.7.0/b-colvis-1.7.0/date-1.0.3/fh-3.1.8/datatables.min.css" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.datatables.net/responsive/2.2.9/css/responsive.dataTables.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <style>
#   </style>
#   <link href="/css/app.css?id=4e84d778ea0d5a252ba8" rel="stylesheet"/>
#   <meta content="StatMando Player Profiles" property="og:title"/>
#   <meta content="" property="og:description"/>
#   <meta content="https://statmando.com/images/og_images/players.jpg" id="og_image" property="og:image"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="StatMando Player Profiles" name="twitter:title"/>
#   <meta content="" name="twitter:description"/>
#   <meta content="@statmando" name="twitter:creator"/>
#   <meta content="@statmando" name="twitter:site"/>
#   <script defer="" src="https://unpkg.com/alpinejs@3.10.2/dist/cdn.min.js">
#   </script>
#   <script src="/js/app.js?id=514f54df4bb93795c380">
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WM7ZBVS');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script src="https://code.jquery.com/jquery-3.5.1.js">
#   </script>
#   <script src="https://cdn.datatables.net/1.10.24/js/jquery.dataTables.min.js">
#   </script>
#   <script src="https://cdn.datatables.net/v/dt/dt-1.10.24/b-1.7.0/b-colvis-1.7.0/date-1.0.3/fh-3.1.8/datatables.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.datatables.net/responsive/2.2.9/js/dataTables.responsive.min.js">
#   </script>
#   <script>
#    function add_dropdown(column) {
#             var colData = column.data().unique();
#             var filterTarget = $(column.header()).attr('data-filter-target');
#             var select = $('<select class="text-sm" style="padding-left: .5rem; padding-right: 2rem;"><option value="">[all]</option></select>')
#                 .appendTo($('#' + filterTarget))
#                 .on('change', function() {
#                     var val = $(this).val()
#                     val = $.fn.dataTable.util.escapeRegex(val);
#                     column.search(val ? '^' + val + '$' : '', true, false).draw();
#                 });
#
#             colData.sort().each(function(d, j) {
#                 if (!d.trim()) {
#                     return;
#                 }
#
#                 select.append('<option value="' + d + '">' + d + '</option>')
#             });
#         }
#
#         function add_search_math(column, id) {
#             var filterTarget = $(column.header()).attr('data-filter-target');
#             var select = $('<input type="text" id="search_math_' + id + '" size=4 placeholder="<, >, =" class="py-2 px-4 text-sm rounded" value=""/>')
#                 .appendTo($('#' + filterTarget))
#         }
#
#         const searchMathPlugin = function(settings, data, dataIndex) {
#             var ret = true; // ret is our complete ROW T/F boolean
#             var values = [];
#
#             var index = -1;
#             $('.filters').each(function() {
#                 index++;
#                 var target = $(this).attr('data-filter-target');
#                 var val = $('#search_math_' + target).val();
#                 values[index] = val;
#             });
#
#             var index = -1;
#             $('.filters').each(function() {
#                 index++;
#
#                 if (settings.aoColumns[index].filter != 'search_math') {
#                     return; // this is a CONTINUE
#                 }
#
#                 // this has to be the current header, not the current place we are typing...
#                 var val = values[index]; // $('#search_math_' + $(this).attr('data-filter-target')).val();
#
#                 if (val.length < 2) {
#                     // don't change ret
#                     return; // this is a CONTINUE
#                 }
#
#                 if (!searchMath(val, data[index])) {
#                     ret = false;
#                     return false; // BREAK we're done, can't show this row
#                 }
#             });
#
#             // this is whether we show the row or not true, show, false don't show
#             return ret;
#         }
#
#         const searchMath = function(val, colVal) {
#             //colVal = parseInt(colVal);
#             colVal = parseFloat(colVal);
#
#             var operator = val.trim().substr(0, 1);
#             val = parseInt(val.substr(1).trim());
#
#             switch (operator) {
#                 case '>':
#                     return colVal > val ? true : false;
#                     break;
#                 case '=':
#                     return val == colVal ? true : false;
#                     break;
#                 case '<':
#                     return colVal < val ? true : false;
#                     break;
#                 default:
#                     throw new Error('invalid operator: the first character must be >, < or =, do something like: ">3000"');
#                     break;
#             }
#         }
#
#         $(document).ready(function() {
#             var table = $('table#generic_datatables').DataTable({
#                 pageLength: 1000,
#                 dom: "ift",
#                 //fixedHeader: true,
#                 order: [], // "don't re-order when first loading"
#                 initComplete: function() {
#                     this.api().columns().every(function(index) {
#                         var id = $(this.header()).attr('data-filter-target');
#                         var filter = $(this.header()).attr('data-filter');
#                         var title = $(this.header()).text().trim();
#
#                         if (filter === '') {
#                             return;
#                         }
#
#                         if (filter === 'dropdown') {
#                             add_dropdown(this);
#                         }
#
#                         if (filter === 'search_math') {
#                             add_search_math(this, id);
#                         }
#
#                     });
#                 }
#             });
#
#             $.fn.dataTable.ext.search.push(searchMathPlugin);
#
#             $('.filter-search_math input').on('keyup', function() {
#                 var val = $(this).val()
#
#                 if (val.length < 2) {
#                     return;
#                 }
#
#                 table.draw();
#             });
#         });
#   </script>
#   <script src="//cdn.jsdelivr.net/npm/jstat@latest/dist/jstat.min.js">
#   </script>
#  </head>
#  <body class="-disabled-antialiased">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WM7ZBVS" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="flex flex-col h-screen w-full">
#    <header class="fixed w-full">
#     <nav class="flex items-center justify-between flex-wrap p-2 md:p-4 border-t-8 border-green-800" style="background-color: #323232">
#      <div class="flex items-center flex-shrink-0 text-white mr-6">
#       <a href="/">
#        <img class="object-contain h-8" src="/images/logo-banner.png"/>
#       </a>
#      </div>
#      <div class="block md:hidden" id="nav" x-data="{ showMenu: false }">
#       <button class="items-center px-3 py-2 border rounded hover:text-white hover:border-white">
#        <svg class="text-white fill-current h-3 w-3" viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg">
#         <title>
#          Menu
#         </title>
#         <path d="M0 3h20v2H0V3zm0 6h20v2H0V9zm0 6h20v2H0v-2z">
#         </path>
#        </svg>
#       </button>
#       <div class="relative">
#        <div class="flex flex-col bg-white absolute right-0 px-4" style="display: none;" x-show="showMenu">
#         <!-- mobile menu -->
#         <a class="border-b border-neutral-100 whitespace-nowrap py-4" href="/">
#          Home
#         </a>
#         <a class="text-white bg-orange-600 hover:bg-orange-700 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold font-xs" href="/rankings/">
#          Rankings
#         </a>
#         <a class="text-white bg-green-800 hover:bg-green-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/players/">
#          Player Profiles
#         </a>
#         <a class="text-white bg-red-800 hover:bg-red-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/monday/">
#          Monday
#         </a>
#         <a class="text-white bg-blue-800 hover:bg-blue-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/head-to-head">
#          Head-to-Head
#         </a>
#         <a class="text-white bg-purple-800 hover:bg-purple-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/stats/">
#          StatZone
#         </a>
#         <a class="border-b border-neutral-100 whitespace-nowrap py-4" href="/data-fix/">
#          Data Fix Portal
#         </a>
#         <a class="border-b border-neutral-100 whitespace-nowrap py-4" href="/contact-us/">
#          Contact Us
#         </a>
#         <a class="border-b border-neutral-100 whitespace-nowrap py-4" href="/about-us/">
#          About Us
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="hidden md:block" x-data="{ showUsMenu: false }">
#       <div class="">
#        <!-- desktop header nav -->
#        <a class="text-white bg-orange-600 hover:bg-orange-700 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold font-xs" href="/rankings/">
#         Rankings
#        </a>
#        <a class="text-white bg-green-800 hover:bg-green-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/players/">
#         Player Profiles
#        </a>
#        <div class="hidden xl:inline text-white bg-green-800 hover:bg-green-900 whitespace-nowrap pr-1 py-4 no-underline m-0">
#         <script>
#          searchPlayers = function () {
#             return {
#                 search: '',
#                 optionsVisible: false,
#                 playersObtained: false,
#                 keyPosition: -1,
#                 players: [{
#                     n: '',
#                     u: '',
#                     p: ''
#                 }],
#                 selected: {
#                     n: null,
#                     u: null,
#                     p: null
#                 },
#                 init() {
#                 },
#                 getPlayers: async function() {
#                     // TODO fetch into localstorage if empty or older than an hour
#                     const response = await fetch('/players/json-list');
#                     this.players = await response.json();
#                     this.playersObtained = true;
#                 },
#                 filtered() {
#                     if (this.search === '') {
#                         return;
#                     }
#
#                     if (this.players.length === 1 && !this.playersObtained) {
#                         this.getPlayers();
#                     }
#
#                     let s = this.search.toLowerCase();
#                     let filteredPlayers = this.players.filter((option) => {
#                         if (!option.n) { // null name won't be any use
#                             return;
#                         }
#
#                         return option.n.toLowerCase().includes(s) || option.p.toString().includes(s)
#                     });
#
#                     if (filteredPlayers.length > 0 && !this.selected) {
#                         this.selected = filteredPlayers[0];
#                     }
#
#                     return filteredPlayers;
#                 },
#                 changeKeyPosition($el, selector, direction) {
#                     if(typeof $el.querySelectorAll(selector) === 'undefined') {
#                         return;
#                     }
#
#                     if($el.querySelectorAll(selector).length === 0) {
#                         return;
#                     }
#
#                     if(direction == 'up') {
#                         this.keyPosition--;
#                     } else if(direction == 'down') {
#                         this.keyPosition++;
#                     }
#
#                     if (this.keyPosition < -1) {
#                         this.keyPosition = -1;
#                     }
#
#                     if (this.keyPosition > 100) {
#                         this.keyPosition = 100;
#                     }
#
#                     if (this.keyPosition >= 0) {
#                         $el.querySelectorAll(selector)[this.keyPosition].focus();
#                     }
#                 }
#             }
#         };
#         </script>
#         <style>
#          div#searchPlayers a.arrowKeyFocus:focus {
#         background-color: #ddd;
#     }
#         </style>
#         <div class="inline-block text-black" id="searchPlayers" x-data="searchPlayers">
#          <input :value="selected.n" id="chosen" name="chosen" type="hidden"/>
#          <input :value="selected.n" autocomplete="off" class="mx-auto m-0 p-2 text-sm w-24" options="" optionsvisible="!optionsVisible;" placeholder="Search" selected="selected" settimeout="" type="text" x-show="!optionsVisible"/>
#          <div class="mx-auto" style="display:none;" x-show="optionsVisible">
#           <input autocomplete="off" class="mx-auto p-2 text-sm" id="playerSearch" placeholder="Search" type="text" x-model.debounce="search"/>
#           <div class="overflow-y-scroll absolute bg-neutral-100 border border-neutral-400 min-w-max text-left" style="max-height: 50vh; z-index: 1;">
#            <template x-for="option in filtered()">
#             <a :href="'/player/' + option.u + '/profile'" class="first:border brder border-b-1 border-gray-300 border-collapse pl-4 pr-6 py-2 block cursor-pointer no-underline arrowKeyFocus" x-text="option.n + ' #' + option.p" xxxclick.prevent="selected = option; optionsVisible = false">
#             </a>
#            </template>
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="hidden xl:inline text-white bg-red-800 hover:bg-red-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/monday/">
#         Monday
#        </a>
#        <a class="hidden xl:inline text-white bg-blue-800 hover:bg-blue-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/head-to-head">
#         Head-to-Head
#        </a>
#        <a class="hidden xl:inline text-white bg-purple-800 hover:bg-purple-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/stats/">
#         StatZone
#        </a>
#        <button class="ml-4 items-center px-2 py-1 border border-neutral-500 rounded text-white hover:border-white">
#         More
#        </button>
#        <!-- desktop header nav "more" -->
#        <div class="relative">
#         <div class="flex flex-col bg-white absolute right-0" style="display: none;" x-show="showUsMenu">
#          <a class="block xl:hidden text-white bg-red-800 hover:bg-red-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/monday/">
#           Monday
#          </a>
#          <a class="block xl:hidden text-white bg-blue-800 hover:bg-blue-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/head-to-head">
#           Head-to-Head
#          </a>
#          <a class="block xl:hidden text-white bg-purple-800 hover:bg-purple-900 whitespace-nowrap px-2 xl:px-4 py-4 uppercase no-underline font-bold" href="/stats/">
#           StatZone
#          </a>
#          <div class="p-4 border border-neutral-400 flex flex-col">
#           <a class="text-black hover:text-neutral-800" href="/data-fix/">
#            Data Fix Portal
#           </a>
#           <a class="text-black hover:text-neutral-800" href="/contact-us/">
#            Contact Us
#           </a>
#           <a class="text-black hover:text-neutral-800" href="/about-us/">
#            About Us
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <main class="container-fluid w-full mx-auto box-border flex-1 mt-32 mb-16">
#     <script>
#      $(document).ready(function() {
#             var table = $('table#players').DataTable({
#                 pageLength: 300,
#                 dom: "",
#                 order: [], // "don't re-order when first loading"
#                 columns: [{
#                     orderable: false
#                 }, {
#                     orderable: false
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }, {
#                 }],
#                 initComplete: function(settings, json) {
#                     this.api().columns([0]).every(function() {
#                         var column = this;
#                         var select = $('<input type="text" id="searchEventName" placeholder="Search" class="py-2 px-4 text-sm rounded" />')
#                             .appendTo($(column.header()).empty())
#                             .on('keyup', function() {
#                                 var val = $(this).val()
#                                 column
#                                     .search(val, false, true)
#                                     .draw();
#                             });
#                     });
#
#                     this.api().columns([1]).every(function() {
#                         var column = this;
#                         var select = $('<select><option value=""></option></select>')
#                             .appendTo($(column.header()).empty())
#                             .on('change', function() {
#                                 var val = $.fn.dataTable.util.escapeRegex(
#                                     $(this).val()
#                                 );
#
#                                 column
#                                     .search(val ? '^' + val + '$' : '', true, false)
#                                     .draw();
#                             });
#
#                         column.data().unique().sort().each(function(d, j) {
#                             select.append('<option value="' + d + '">' + d + '</option>')
#                         });
#                     });
#                 }
#             });
#         });
#     </script>
#     <div class="w-full px-4 bg-green-500 text-red text-center mb-4 -mt-4 italic font-thin">
#     </div>
#     <h1 class="w-full text-2xl lg:w-6/12 lg:text-4xl font-bold mx-auto text-center mb-8 bg-green-900 text-white p-6 shadow">
#      StatMando Player Profiles
#     </h1>
#     <div class="w-full lg:w-11/12 text-right text-xs text-neutral-300">
#      Data does not include special events, leagues and X tiers. Click on the player name to see their StatMando profile.
#     </div>
#     <div class="overflow-x-auto w-full lg:w-11/12 mx-auto border border-t-8 border-neutral-700 box-border p-0 m-0">
#      <table class="" id="players">
#       <thead class="bg-neutral-300 border-neutral-900 text-neutral-900 cursor-pointer">
#        <tr class="font-small p-8">
#         <th class="text-left py-2 px-4 text-sm px-4">
#          Name
#         </th>
#         <th class="text-left text-sm px-4">
#          Division
#         </th>
#         <th class="text-left text-sm px-4">
#          Events
#         </th>
#         <th class="text-left whitespace-nowrap text-sm px-4">
#          Wins
#         </th>
#         <th class="text-left text-sm px-4">
#          %
#         </th>
#         <th class="text-left whitespace-nowrap text-sm px-4">
#          Podiums
#         </th>
#         <th class="text-left text-sm px-4">
#          %
#         </th>
#         <th class="text-left text-sm px-4">
#          Top Ten
#         </th>
#         <th class="text-left text-sm px-4">
#          %
#         </th>
#         <th class="text-left text-sm px-4">
#          Rounds
#         </th>
#         <th class="text-left text-sm px-4">
#          Cashed
#         </th>
#         <th class="text-left text-sm px-4">
#          %
#         </th>
#         <th class="text-left whitespace-nowrap text-sm px-4">
#          Throws
#         </th>
#         <th class="text-left whitespace-nowrap text-sm px-4">
#          Cash/Throw
#         </th>
#         <th class="text-left text-sm px-4">
#          Total Cash
#         </th>
#        </tr>
#       </thead>
#       <tfoot>
#       </tfoot>
#       <tbody>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/ezra-aderhold/profile">
#            Ezra Aderhold
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          96
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          7
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          7.29%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          17
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          17.71%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          36
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          37.5%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          286
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          85
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          88.54%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          17,391
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $3.67
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $63,863
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/catrina-allen/profile">
#            Catrina Allen
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          FPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          383
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          180
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          47%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          296
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          77.28%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          369
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          96.34%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          1,252
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          348
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          90.86%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          79,261
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $3.97
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $314,809
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/jennifer-allen/profile">
#            Jennifer Allen
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          FPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          276
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          151
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          54.71%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          208
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          75.36%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          260
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          94.2%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          894
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          254
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          92.03%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          56,840
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $1.55
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $87,956
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/sai-ananda/profile">
#            Sai Ananda
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          FPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          96
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          55
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          57.29%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          65
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          67.71%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          85
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          88.54%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          286
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          53
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          55.21%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          19,011
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $0.88
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $16,815
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/zoe-andyke/profile">
#            Zoe Andyke
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          FPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          186
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          37
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          19.89%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          77
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          41.4%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          136
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          73.12%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          566
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          110
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          59.14%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          38,620
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $0.62
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $24,047
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/josh-anthon/profile">
#            Josh Anthon
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          228
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          50
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          21.93%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          100
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          43.86%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          182
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          79.82%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          877
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          215
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          94.3%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          47,409
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $3.38
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $160,250
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/niklas-anttila/profile">
#            Niklas Anttila
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          76
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          19
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          25%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          36
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          47.37%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          61
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          80.26%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          237
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          51
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          67.11%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          13,854
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $4.02
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $55,682
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/dion-arlyn/profile">
#            Dion Arlyn
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          206
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          37
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          17.96%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          86
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          41.75%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          157
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          76.21%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          620
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          165
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          80.1%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          34,632
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $1.15
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $39,987
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/gavin-babcock/profile">
#            Gavin Babcock
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          78
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          6
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          7.69%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          14
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          17.95%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          30
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          38.46%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          221
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          43
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          55.13%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          13,688
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $1.55
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $21,284
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/anthony-barela/profile">
#            Anthony Barela
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          181
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          31
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          17.13%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          58
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          32.04%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          112
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          61.88%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          570
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          113
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          62.43%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          33,505
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $2.62
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $87,741
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/tim-barham/profile">
#            Tim Barham
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          288
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          76
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          26.39%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          145
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          50.35%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          200
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          69.44%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          759
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          240
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          83.33%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          43,509
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $2.40
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $104,482
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/gregg-barsby/profile">
#            Gregg Barsby
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          455
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          80
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          17.58%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          180
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          39.56%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          297
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          65.27%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          1,566
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          377
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          82.86%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          88,731
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $2.69
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $238,880
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/matt-bell/profile">
#            Matt Bell
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          260
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          36
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          13.85%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          74
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          28.46%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          132
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          50.77%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          827
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          208
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          80%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          48,827
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $2.33
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $113,549
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/carrie-berlogar/profile">
#            Carrie Berlogar
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          FPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          224
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          77
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          34.38%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          180
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          80.36%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          222
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          99.11%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          852
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          210
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          93.75%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          54,475
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $1.37
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $74,813
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/henna-blomroos/profile">
#            Henna Blomroos
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          FPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          93
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          35
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          37.63%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          73
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          78.49%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          90
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          96.77%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          316
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          72
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          77.42%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          21,210
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $2.40
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $50,965
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/philo-brathwaite/profile">
#            Philo Brathwaite
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
# ...
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          53,947
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $2.14
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $115,265
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/casey-white/profile">
#            Casey White
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          150
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          20
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          13.33%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          44
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          29.33%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          77
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          51.33%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          421
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          100
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          66.67%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          24,765
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $2.05
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $50,671
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/ellen-widboom/profile">
#            Ellen Widboom
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          FPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          235
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          100
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          42.55%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          150
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          63.83%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          185
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          78.72%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          672
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          170
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          72.34%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          44,570
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $1.29
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $57,486
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/bradley-williams/profile">
#            Bradley Williams
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          386
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          126
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          32.64%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          205
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          53.11%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          306
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          79.27%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          1,169
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          357
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          92.49%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          64,503
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $3.07
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $198,036
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/scott-withers/profile">
#            Scott Withers
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          290
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          130
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          44.83%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          190
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          65.52%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          239
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          82.41%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          803
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          273
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          94.14%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          43,371
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $2.49
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $107,872
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/ricky-wysocki/profile">
#            Ricky Wysocki
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          MPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          377
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          123
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          32.63%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          245
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          64.99%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          339
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          89.92%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          1,254
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          332
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          88.06%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          68,849
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $8.55
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $588,494
#         </td>
#        </tr>
#        <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#         <td class="name text-left px-4 whitespace-nowrap">
#          <div class="overflow-hidden whitespace-nowrap w-full">
#           <a class="text-sm" href="/player/heather-young/profile">
#            Heather Young
#           </a>
#          </div>
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          FPO
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          58
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          18
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          31.03%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          32
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          55.17%
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          48
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          82.76%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          162
#         </td>
#         <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#          50
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          86.21%
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          10,433
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $3.79
#         </td>
#         <td class="border-l border-neutral-200 text-left text-sm px-4">
#          $39,529
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#    </main>
#    <footer class="bg-neutral-200 text-black-400 text-center text-base">
#     <div class="py-8">
#      <ul class="flex flex-col md:flex-row justify-center space-x-4">
#       <li>
#        <i class="fab fa-twitter">
#        </i>
#        <a href="https://twitter.com/statmando/">
#         @statmando
#        </a>
#       </li>
#       <li>
#        <i class="fab fa-instagram">
#        </i>
#        <a href="https://instagram.com/statmandodg/">
#         @statmandodg
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="flex flex-row justify-center mx-auto w-full md:w-6/12 leading-6">
#      <div class="p-4 pr-0">
#       Data from
#      </div>
#      <div class="p-4 pl-2">
#       <a href="https://www.pdga.com/" target="_blank">
#        <img class="w-16" src="/images/partners/pdga-logo.png"/>
#       </a>
#      </div>
#     </div>
#     <div class="py-4">
#      StatMando™, © 2021-2022 Disc Golf Professional Services, LLC
#     </div>
#    </footer>
#   </div>
#   <div class="js-cookie-consent cookie-consent fixed bottom-0 inset-x-0 pb-2">
#    <div class="max-w-7xl mx-auto px-6">
#     <div class="p-2 rounded-lg bg-yellow-100">
#      <div class="flex items-center justify-between flex-wrap">
#       <div class="w-0 flex-1 items-center hidden md:inline">
#        <p class="ml-3 text-yellow-600 cookie-consent__message">
#         We use cookies to help us understand how our web site is used. Please consent to using cookies.
#        </p>
#       </div>
#       <div class="mt-2 flex-shrink-0 w-full sm:mt-0 sm:w-auto">
#        <a class="js-cookie-consent-agree cookie-consent__agree cursor-pointer flex items-center justify-center px-4 py-2 rounded-md text-sm font-medium text-yellow-800 bg-yellow-400 hover:bg-yellow-300">
#         Allow cookies
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    window.laravelCookieConsent = (function () {
#
#             const COOKIE_VALUE = 1;
#             const COOKIE_DOMAIN = 'statmando.com';
#
#             function consentWithCookies() {
#                 setCookie('laravel_cookie_consent', COOKIE_VALUE, 7300);
#                 hideCookieDialog();
#             }
#
#             function cookieExists(name) {
#                 return (document.cookie.split('; ').indexOf(name + '=' + COOKIE_VALUE) !== -1);
#             }
#
#             function hideCookieDialog() {
#                 const dialogs = document.getElementsByClassName('js-cookie-consent');
#
#                 for (let i = 0; i < dialogs.length; ++i) {
#                     dialogs[i].style.display = 'none';
#                 }
#             }
#
#             function setCookie(name, value, expirationInDays) {
#                 const date = new Date();
#                 date.setTime(date.getTime() + (expirationInDays * 24 * 60 * 60 * 1000));
#                 document.cookie = name + '=' + value
#                     + ';expires=' + date.toUTCString()
#                     + ';domain=' + COOKIE_DOMAIN
#                     + ';path=/'
#                     + ';samesite=lax';
#             }
#
#             if (cookieExists('laravel_cookie_consent')) {
#                 hideCookieDialog();
#             }
#
#             const buttons = document.getElementsByClassName('js-cookie-consent-agree');
#
#             for (let i = 0; i < buttons.length; ++i) {
#                 buttons[i].addEventListener('click', consentWithCookies);
#             }
#
#             return {
#                 consentWithCookies: consentWithCookies,
#                 hideCookieDialog: hideCookieDialog
#             };
#         })();
#   </script>
#   <script>
#    (function(){var js = "window['__CF$cv$params']={r:'769b04585babb074',m:'8GckDUshwZD_VapKj29fbzt582gVyZAGWSDM9kgSxgM-1668379309-0-AcKLvsZLozD9gBLPUQjz9QyKJpsVNDpCTbSgM+XXKuJ+z0oOmAP1ojEb8LFrEWIwlvbmkp+00i5PzbhzRhl/IegNO2IUCJIz3j94PpRnZcMTh0FCwmgRuwe3zr6p+0O7oA==',s:[0x50a45d8952,0x3c6d3959b5],u:'/cdn-cgi/challenge-platform/h/b'};var now=Date.now()/1000,offset=14400,ts=''+(Math.floor(now)-Math.floor(now%offset)),_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/h/b/scripts/alpha/invisible.js?ts='+ts,document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();
#   </script>
#  </body>
# </html>

# %%
soup.findAll('table')
# Out:
# [<table class="" id="players">
#  <thead class="bg-neutral-300 border-neutral-900 text-neutral-900 cursor-pointer">
#  <tr class="font-small p-8">
#  <th class="text-left py-2 px-4 text-sm px-4">
#                          Name
#                      </th>
#  <th class="text-left text-sm px-4">
#                          Division
#                      </th>
#  <th class="text-left text-sm px-4">
#                          Events
#                      </th>
#  <th class="text-left whitespace-nowrap text-sm px-4">
#                          Wins
#                      </th>
#  <th class="text-left text-sm px-4">
#                          %
#                      </th>
#  <th class="text-left whitespace-nowrap text-sm px-4">
#                          Podiums
#                      </th>
#  <th class="text-left text-sm px-4">
#                          %
#                      </th>
#  <th class="text-left text-sm px-4">
#                          Top Ten
#                      </th>
#  <th class="text-left text-sm px-4">
#                          %
#                      </th>
#  <th class="text-left text-sm px-4">
#                          Rounds
#                      </th>
#  <th class="text-left text-sm px-4">
#                          Cashed
#                      </th>
#  <th class="text-left text-sm px-4">
#                          %
#                      </th>
#  <th class="text-left whitespace-nowrap text-sm px-4">
#                          Throws
#                      </th>
#  <th class="text-left whitespace-nowrap text-sm px-4">
#                          Cash/Throw
#                      </th>
#  <th class="text-left text-sm px-4">
#                          Total Cash
#                      </th>
#  </tr>
#  </thead>
#  <tfoot>
#  </tfoot>
#  <tbody>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/ezra-aderhold/profile">Ezra Aderhold</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          96
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          7
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          7.29%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          17
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          17.71%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          36
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          37.5%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          286
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          85
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          88.54%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          17,391
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $3.67
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $63,863
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/catrina-allen/profile">Catrina Allen</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          383
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          180
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          47%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          296
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          77.28%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          369
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          96.34%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          1,252
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          348
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          90.86%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          79,261
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $3.97
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $314,809
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/jennifer-allen/profile">Jennifer Allen</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          276
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          151
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          54.71%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          208
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          75.36%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          260
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          94.2%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          894
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          254
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          92.03%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          56,840
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $1.55
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $87,956
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/sai-ananda/profile">Sai Ananda</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          96
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          55
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          57.29%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          65
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          67.71%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          85
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          88.54%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          286
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          53
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          55.21%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          19,011
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $0.88
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $16,815
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/zoe-andyke/profile">Zoe Andyke</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          186
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          37
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          19.89%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          77
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          41.4%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          136
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          73.12%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          566
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          110
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          59.14%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          38,620
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $0.62
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $24,047
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/josh-anthon/profile">Josh Anthon</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          228
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          50
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          21.93%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          100
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          43.86%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          182
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          79.82%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          877
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          215
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          94.3%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          47,409
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $3.38
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $160,250
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/niklas-anttila/profile">Niklas Anttila</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          76
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          19
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          25%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          36
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          47.37%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          61
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          80.26%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          237
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          51
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          67.11%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          13,854
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $4.02
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $55,682
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/dion-arlyn/profile">Dion Arlyn</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          206
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          37
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          17.96%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          86
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          41.75%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          157
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          76.21%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          620
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          165
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          80.1%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          34,632
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $1.15
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $39,987
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/gavin-babcock/profile">Gavin Babcock</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          78
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          6
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          7.69%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          14
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          17.95%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          30
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          38.46%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          221
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          43
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          55.13%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          13,688
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $1.55
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $21,284
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/anthony-barela/profile">Anthony Barela</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          181
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          31
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          17.13%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          58
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          32.04%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          112
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          61.88%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          570
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          113
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          62.43%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          33,505
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.62
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $87,741
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/tim-barham/profile">Tim Barham</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          288
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          76
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          26.39%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          145
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          50.35%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          200
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          69.44%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          759
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          240
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          83.33%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          43,509
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.40
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $104,482
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/gregg-barsby/profile">Gregg Barsby</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          455
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          80
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          17.58%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          180
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          39.56%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          297
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          65.27%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          1,566
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          377
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          82.86%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          88,731
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.69
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $238,880
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/matt-bell/profile">Matt Bell</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          260
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          36
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          13.85%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          74
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          28.46%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          132
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          50.77%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          827
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          208
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          80%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          48,827
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.33
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $113,549
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/carrie-berlogar/profile">Carrie Berlogar</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          224
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          77
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          34.38%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          180
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          80.36%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          222
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          99.11%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          852
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          210
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          93.75%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          54,475
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $1.37
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $74,813
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/henna-blomroos/profile">Henna Blomroos</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          93
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          35
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          37.63%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          73
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          78.49%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          90
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          96.77%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          316
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          72
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          77.42%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          21,210
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.40
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $50,965
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/philo-brathwaite/profile">Philo Brathwaite</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          349
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          38
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          10.89%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          115
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          32.95%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          200
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          57.31%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          1,166
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          303
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          86.82%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          65,951
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.29
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $151,312
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/steve-brinster/profile">Steve Brinster</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          419
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          107
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          25.54%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          203
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          48.45%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          320
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          76.37%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          1,393
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          386
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          92.12%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          77,764
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.82
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $219,132
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/lance-brown/profile">Lance Brown</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          310
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          20
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          6.45%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          74
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          23.87%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          184
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          59.35%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          947
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          198
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          63.87%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          54,563
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $0.92
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $50,323
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/patrick-brown/profile">Patrick Brown</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          310
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          115
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          37.1%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          197
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          63.55%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          242
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          78.06%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          1,068
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          250
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          80.65%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          61,988
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.60
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $161,306
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/gannon-buhr/profile">Gannon Buhr</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          99
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          25
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          25.25%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          44
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          44.44%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          73
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          73.74%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          288
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          43
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          43.43%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          17,475
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $6.10
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $106,612
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/robert-burridge/profile">Robert Burridge</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          53
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          21
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          39.62%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          31
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          58.49%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          40
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          75.47%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          140
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          17
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          32.08%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          8,643
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $1.54
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $13,296
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/benjamin-callaway/profile">Benjamin Callaway</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          196
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          27
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          13.78%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          53
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          27.04%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          114
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          58.16%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          591
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          132
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          67.35%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          34,494
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $1.74
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $59,892
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/courtney-cannon/profile">Courtney Cannon</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          116
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          24
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          20.69%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          55
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          47.41%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          75
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          64.66%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          327
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          40
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          34.48%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          22,853
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $0.42
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $9,699
#                      </td>
#  </tr>
# ...
#  <a class="text-sm" href="/player/madison-walker/profile">Madison Walker</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          168
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          22
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          13.1%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          53
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          31.55%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          123
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          73.21%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          555
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          129
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          76.79%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          37,177
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $1.42
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $52,628
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/jessica-weese/profile">Jessica Weese</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          265
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          70
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          26.42%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          137
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          51.7%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          223
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          84.15%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          833
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          223
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          84.15%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          53,947
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.14
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $115,265
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/casey-white/profile">Casey White</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          150
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          20
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          13.33%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          44
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          29.33%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          77
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          51.33%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          421
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          100
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          66.67%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          24,765
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.05
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $50,671
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/ellen-widboom/profile">Ellen Widboom</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          235
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          100
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          42.55%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          150
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          63.83%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          185
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          78.72%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          672
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          170
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          72.34%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          44,570
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $1.29
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $57,486
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/bradley-williams/profile">Bradley Williams</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          386
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          126
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          32.64%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          205
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          53.11%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          306
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          79.27%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          1,169
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          357
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          92.49%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          64,503
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $3.07
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $198,036
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/scott-withers/profile">Scott Withers</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          290
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          130
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          44.83%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          190
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          65.52%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          239
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          82.41%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          803
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          273
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          94.14%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          43,371
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $2.49
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $107,872
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/ricky-wysocki/profile">Ricky Wysocki</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          MPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          377
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          123
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          32.63%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          245
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          64.99%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          339
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          89.92%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          1,254
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          332
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          88.06%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          68,849
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $8.55
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $588,494
#                      </td>
#  </tr>
#  <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
#  <td class="name text-left px-4 whitespace-nowrap">
#  <div class="overflow-hidden whitespace-nowrap w-full">
#  <a class="text-sm" href="/player/heather-young/profile">Heather Young</a>
#  </div>
#  </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          FPO
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          58
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          18
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          31.03%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          32
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          55.17%
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          48
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          82.76%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          162
#                      </td>
#  <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                          50
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          86.21%
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          10,433
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $3.79
#                      </td>
#  <td class="border-l border-neutral-200 text-left text-sm px-4">
#                          $39,529
#                      </td>
#  </tr>
#  </tbody>
#  </table>]

# %%
soup.find('table', attrs={'id':'players'})
# Out:
# <table class="" id="players">
# <thead class="bg-neutral-300 border-neutral-900 text-neutral-900 cursor-pointer">
# <tr class="font-small p-8">
# <th class="text-left py-2 px-4 text-sm px-4">
#                         Name
#                     </th>
# <th class="text-left text-sm px-4">
#                         Division
#                     </th>
# <th class="text-left text-sm px-4">
#                         Events
#                     </th>
# <th class="text-left whitespace-nowrap text-sm px-4">
#                         Wins
#                     </th>
# <th class="text-left text-sm px-4">
#                         %
#                     </th>
# <th class="text-left whitespace-nowrap text-sm px-4">
#                         Podiums
#                     </th>
# <th class="text-left text-sm px-4">
#                         %
#                     </th>
# <th class="text-left text-sm px-4">
#                         Top Ten
#                     </th>
# <th class="text-left text-sm px-4">
#                         %
#                     </th>
# <th class="text-left text-sm px-4">
#                         Rounds
#                     </th>
# <th class="text-left text-sm px-4">
#                         Cashed
#                     </th>
# <th class="text-left text-sm px-4">
#                         %
#                     </th>
# <th class="text-left whitespace-nowrap text-sm px-4">
#                         Throws
#                     </th>
# <th class="text-left whitespace-nowrap text-sm px-4">
#                         Cash/Throw
#                     </th>
# <th class="text-left text-sm px-4">
#                         Total Cash
#                     </th>
# </tr>
# </thead>
# <tfoot>
# </tfoot>
# <tbody>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/ezra-aderhold/profile">Ezra Aderhold</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         96
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         7
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         7.29%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         17
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17.71%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         36
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         37.5%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         286
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         85
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         88.54%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17,391
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $3.67
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $63,863
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/catrina-allen/profile">Catrina Allen</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         383
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         180
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         47%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         296
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         77.28%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         369
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         96.34%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         1,252
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         348
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         90.86%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         79,261
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $3.97
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $314,809
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/jennifer-allen/profile">Jennifer Allen</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         276
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         151
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         54.71%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         208
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         75.36%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         260
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         94.2%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         894
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         254
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         92.03%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         56,840
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.55
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $87,956
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/sai-ananda/profile">Sai Ananda</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         96
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         55
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         57.29%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         65
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         67.71%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         85
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         88.54%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         286
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         53
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         55.21%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         19,011
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $0.88
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $16,815
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/zoe-andyke/profile">Zoe Andyke</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         186
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         37
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         19.89%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         77
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         41.4%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         136
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         73.12%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         566
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         110
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         59.14%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         38,620
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $0.62
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $24,047
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/josh-anthon/profile">Josh Anthon</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         228
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         50
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         21.93%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         100
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         43.86%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         182
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         79.82%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         877
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         215
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         94.3%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         47,409
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $3.38
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $160,250
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/niklas-anttila/profile">Niklas Anttila</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         76
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         19
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         25%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         36
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         47.37%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         61
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         80.26%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         237
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         51
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         67.11%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         13,854
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $4.02
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $55,682
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/dion-arlyn/profile">Dion Arlyn</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         206
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         37
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17.96%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         86
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         41.75%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         157
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         76.21%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         620
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         165
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         80.1%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         34,632
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.15
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $39,987
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/gavin-babcock/profile">Gavin Babcock</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         78
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         6
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         7.69%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         14
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17.95%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         30
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         38.46%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         221
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         43
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         55.13%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         13,688
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.55
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $21,284
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/anthony-barela/profile">Anthony Barela</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         181
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         31
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17.13%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         58
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         32.04%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         112
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         61.88%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         570
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         113
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         62.43%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         33,505
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.62
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $87,741
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/tim-barham/profile">Tim Barham</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         288
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         76
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         26.39%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         145
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         50.35%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         200
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         69.44%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         759
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         240
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         83.33%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         43,509
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.40
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $104,482
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/gregg-barsby/profile">Gregg Barsby</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         455
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         80
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17.58%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         180
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         39.56%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         297
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         65.27%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         1,566
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         377
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         82.86%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         88,731
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.69
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $238,880
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/matt-bell/profile">Matt Bell</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         260
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         36
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         13.85%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         74
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         28.46%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         132
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         50.77%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         827
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         208
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         80%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         48,827
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.33
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $113,549
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/carrie-berlogar/profile">Carrie Berlogar</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         224
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         77
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         34.38%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         180
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         80.36%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         222
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         99.11%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         852
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         210
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         93.75%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         54,475
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.37
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $74,813
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/henna-blomroos/profile">Henna Blomroos</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         93
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         35
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         37.63%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         73
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         78.49%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         90
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         96.77%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         316
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         72
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         77.42%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         21,210
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.40
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $50,965
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/philo-brathwaite/profile">Philo Brathwaite</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         349
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         38
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         10.89%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         115
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         32.95%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         200
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         57.31%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         1,166
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         303
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         86.82%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         65,951
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.29
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $151,312
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/steve-brinster/profile">Steve Brinster</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         419
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         107
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         25.54%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         203
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         48.45%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         320
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         76.37%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         1,393
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         386
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         92.12%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         77,764
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.82
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $219,132
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/lance-brown/profile">Lance Brown</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         310
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         20
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         6.45%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         74
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         23.87%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         184
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         59.35%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         947
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         198
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         63.87%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         54,563
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $0.92
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $50,323
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/patrick-brown/profile">Patrick Brown</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         310
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         115
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         37.1%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         197
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         63.55%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         242
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         78.06%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         1,068
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         250
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         80.65%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         61,988
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.60
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $161,306
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/gannon-buhr/profile">Gannon Buhr</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         99
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         25
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         25.25%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         44
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         44.44%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         73
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         73.74%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         288
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         43
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         43.43%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17,475
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $6.10
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $106,612
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/robert-burridge/profile">Robert Burridge</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         53
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         21
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         39.62%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         31
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         58.49%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         40
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         75.47%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         140
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         17
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         32.08%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         8,643
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.54
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $13,296
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/benjamin-callaway/profile">Benjamin Callaway</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         196
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         27
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         13.78%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         53
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         27.04%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         114
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         58.16%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         591
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         132
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         67.35%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         34,494
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.74
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $59,892
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/courtney-cannon/profile">Courtney Cannon</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         116
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         24
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         20.69%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         55
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         47.41%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         75
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         64.66%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         327
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         40
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         34.48%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         22,853
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $0.42
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $9,699
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/aj-carey/profile">AJ Carey</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         253
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         20
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         7.91%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         62
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         24.51%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         127
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
# ...
#                         $1.17
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $49,421
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/madison-walker/profile">Madison Walker</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         168
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         22
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         13.1%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         53
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         31.55%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         123
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         73.21%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         555
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         129
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         76.79%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         37,177
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.42
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $52,628
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/jessica-weese/profile">Jessica Weese</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         265
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         70
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         26.42%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         137
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         51.7%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         223
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         84.15%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         833
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         223
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         84.15%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         53,947
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.14
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $115,265
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/casey-white/profile">Casey White</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         150
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         20
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         13.33%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         44
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         29.33%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         77
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         51.33%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         421
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         100
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         66.67%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         24,765
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.05
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $50,671
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/ellen-widboom/profile">Ellen Widboom</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         235
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         100
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         42.55%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         150
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         63.83%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         185
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         78.72%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         672
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         170
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         72.34%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         44,570
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.29
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $57,486
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/bradley-williams/profile">Bradley Williams</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         386
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         126
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         32.64%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         205
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         53.11%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         306
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         79.27%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         1,169
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         357
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         92.49%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         64,503
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $3.07
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $198,036
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/scott-withers/profile">Scott Withers</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         290
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         130
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         44.83%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         190
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         65.52%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         239
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         82.41%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         803
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         273
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         94.14%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         43,371
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $2.49
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $107,872
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/ricky-wysocki/profile">Ricky Wysocki</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         377
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         123
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         32.63%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         245
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         64.99%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         339
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         89.92%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         1,254
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         332
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         88.06%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         68,849
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $8.55
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $588,494
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/heather-young/profile">Heather Young</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         58
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         18
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         31.03%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         32
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         55.17%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         48
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         82.76%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         162
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         50
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         86.21%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         10,433
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $3.79
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $39,529
#                     </td>
# </tr>
# </tbody>
# </table>

# %%
table_html = str(soup.find('table', attrs={'id':'players'}))

HTML(table_html)
# Out:
# <table class="" id="players">
# <thead class="bg-neutral-300 border-neutral-900 text-neutral-900 cursor-pointer">
# <tr class="font-small p-8">
# <th class="text-left py-2 px-4 text-sm px-4">
#                         Name
#                     </th>
# <th class="text-left text-sm px-4">
#                         Division
#                     </th>
# <th class="text-left text-sm px-4">
#                         Events
#                     </th>
# <th class="text-left whitespace-nowrap text-sm px-4">
#                         Wins
#                     </th>
# <th class="text-left text-sm px-4">
#                         %
#                     </th>
# <th class="text-left whitespace-nowrap text-sm px-4">
#                         Podiums
#                     </th>
# <th class="text-left text-sm px-4">
#                         %
#                     </th>
# <th class="text-left text-sm px-4">
#                         Top Ten
#                     </th>
# <th class="text-left text-sm px-4">
#                         %
#                     </th>
# <th class="text-left text-sm px-4">
#                         Rounds
#                     </th>
# <th class="text-left text-sm px-4">
#                         Cashed
#                     </th>
# <th class="text-left text-sm px-4">
#                         %
#                     </th>
# <th class="text-left whitespace-nowrap text-sm px-4">
#                         Throws
#                     </th>
# <th class="text-left whitespace-nowrap text-sm px-4">
#                         Cash/Throw
#                     </th>
# <th class="text-left text-sm px-4">
#                         Total Cash
#                     </th>
# </tr>
# </thead>
# <tfoot>
# </tfoot>
# <tbody>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/ezra-aderhold/profile">Ezra Aderhold</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         MPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         96
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         7
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         7.29%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         17
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17.71%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         36
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         37.5%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         286
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         85
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         88.54%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         17,391
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $3.67
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $63,863
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/catrina-allen/profile">Catrina Allen</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         383
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         180
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         47%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         296
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         77.28%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         369
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         96.34%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         1,252
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         348
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         90.86%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         79,261
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $3.97
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $314,809
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/jennifer-allen/profile">Jennifer Allen</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         276
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         151
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         54.71%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         208
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         75.36%
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         260
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         94.2%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         894
#                     </td>
# <td class="border-l-2 border-neutral-300 text-left text-sm px-4">
#                         254
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         92.03%
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         56,840
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $1.55
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         $87,956
#                     </td>
# </tr>
# <tr class="hover:bg-neutral-100 border-neutral-100 py-4 font-normal text-neutral-900">
# <td class="name text-left px-4 whitespace-nowrap">
# <div class="overflow-hidden whitespace-nowrap w-full">
# <a class="text-sm" href="/player/sai-ananda/profile">Sai Ananda</a>
# </div>
# </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">
#                         FPO
#                     </td>
# <td class="border-l border-neutral-200 text-left text-sm px-4">

# %%
player_stats_career = pd.read_html(str(soup.find('table', attrs={'id':'players'})))[0]
player_stats_career
# Out:
#                  Name Division  Events  Wins       %  Podiums     %.1  \
# 0       Ezra Aderhold      MPO      96     7   7.29%       17  17.71%
# 1       Catrina Allen      FPO     383   180     47%      296  77.28%
# 2      Jennifer Allen      FPO     276   151  54.71%      208  75.36%
# 3          Sai Ananda      FPO      96    55  57.29%       65  67.71%
# 4          Zoe Andyke      FPO     186    37  19.89%       77   41.4%
# ..                ...      ...     ...   ...     ...      ...     ...
# 154     Ellen Widboom      FPO     235   100  42.55%      150  63.83%
# 155  Bradley Williams      MPO     386   126  32.64%      205  53.11%
# 156     Scott Withers      MPO     290   130  44.83%      190  65.52%
# 157     Ricky Wysocki      MPO     377   123  32.63%      245  64.99%
# 158     Heather Young      FPO      58    18  31.03%       32  55.17%
#
#      Top Ten     %.2  Rounds  Cashed     %.3  Throws Cash/Throw Total Cash
# 0         36   37.5%     286      85  88.54%   17391      $3.67    $63,863
# 1        369  96.34%    1252     348  90.86%   79261      $3.97   $314,809
# 2        260   94.2%     894     254  92.03%   56840      $1.55    $87,956
# 3         85  88.54%     286      53  55.21%   19011      $0.88    $16,815
# 4        136  73.12%     566     110  59.14%   38620      $0.62    $24,047
# ..       ...     ...     ...     ...     ...     ...        ...        ...
# 154      185  78.72%     672     170  72.34%   44570      $1.29    $57,486
# 155      306  79.27%    1169     357  92.49%   64503      $3.07   $198,036
# 156      239  82.41%     803     273  94.14%   43371      $2.49   $107,872
# 157      339  89.92%    1254     332  88.06%   68849      $8.55   $588,494
# 158       48  82.76%     162      50  86.21%   10433      $3.79    $39,529
#
# [159 rows x 15 columns]

# %%
player_stats_career.to_csv('../data/player-stats-career.csv')
